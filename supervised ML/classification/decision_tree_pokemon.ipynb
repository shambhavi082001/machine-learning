# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/digipodium/Datasets/main/classfication/pokemon_type.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# 1      80  ...  Green       True    0.875     Monster        Grass
# 2     100  ...  Green       True    0.875     Monster        Grass
# 3      50  ...    Red       True    0.875     Monster       Dragon
# 4      65  ...    Red       True    0.875     Monster       Dragon
#
#    hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# ...

# %%
df.shape
# Out:
# (721, 23)

# %%
df.rename(columns={'Type_1':'primary_type','Type_2':'secondary_type'},inplace=True)

# %%
df.head()
# Out:
#    Number        Name primary_type secondary_type  Total  HP  Attack  Defense  \
# 0       1   Bulbasaur        Grass         Poison    318  45      49       49
# 1       2     Ivysaur        Grass         Poison    405  60      62       63
# 2       3    Venusaur        Grass         Poison    525  80      82       83
# 3       4  Charmander         Fire            NaN    309  39      52       43
# 4       5  Charmeleon         Fire            NaN    405  58      64       58
#
#    Sp_Atk  Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65      65  ...  Green       True    0.875     Monster        Grass
# 1      80      80  ...  Green       True    0.875     Monster        Grass
# 2     100     100  ...  Green       True    0.875     Monster        Grass
# 3      60      50  ...    Red       True    0.875     Monster       Dragon
# 4      80      65  ...    Red       True    0.875     Monster       Dragon
#
# ...

# %%
df.describe()
# Out:
#           Number       Total          HP      Attack     Defense      Sp_Atk  \
# count  721.00000  721.000000  721.000000  721.000000  721.000000  721.000000
# mean   361.00000  417.945908   68.380028   75.013870   70.808599   68.737864
# std    208.27906  109.663671   25.848272   28.984475   29.296558   28.788005
# min      1.00000  180.000000    1.000000    5.000000    5.000000   10.000000
# 25%    181.00000  320.000000   50.000000   53.000000   50.000000   45.000000
# 50%    361.00000  424.000000   65.000000   74.000000   65.000000   65.000000
# 75%    541.00000  499.000000   80.000000   95.000000   85.000000   90.000000
# max    721.00000  720.000000  255.000000  165.000000  230.000000  154.000000
#
#            Sp_Def       Speed  Generation     Pr_Male    Height_m   Weight_kg  \
# count  721.000000  721.000000  721.000000  644.000000  721.000000  721.000000
# mean    69.291262   65.714286    3.323162    0.553377    1.144979   56.773370
# ...

# %%
df["primary_type"]
# Out:
# 0        Grass
# 1        Grass
# 2        Grass
# 3         Fire
# 4         Fire
#         ...
# 716       Dark
# 717     Dragon
# 718       Rock
# 719    Psychic
# 720       Fire
# Name: primary_type, Length: 721, dtype: object

# %%
df["primary_type"]=='Grass'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 716    False
# 717    False
# 718    False
# 719    False
# 720    False
# Name: primary_type, Length: 721, dtype: bool

# %%
grass_pokemon=df[df["primary_type"]=='Grass']

# %%
grass_pokemon.head()
# Out:
#     Number       Name primary_type secondary_type  Total  HP  Attack  Defense  \
# 0        1  Bulbasaur        Grass         Poison    318  45      49       49
# 1        2    Ivysaur        Grass         Poison    405  60      62       63
# 2        3   Venusaur        Grass         Poison    525  80      82       83
# 42      43     Oddish        Grass         Poison    320  45      50       55
# 43      44      Gloom        Grass         Poison    395  60      65       70
#
#     Sp_Atk  Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0       65      65  ...  Green       True    0.875     Monster        Grass
# 1       80      80  ...  Green       True    0.875     Monster        Grass
# 2      100     100  ...  Green       True    0.875     Monster        Grass
# 42      75      65  ...   Blue       True    0.500       Grass          NaN
# 43      85      75  ...   Blue       True    0.500       Grass          NaN
#
# ...

# %%
water_pokemon=df[df['primary_type']=="Water"]

# %%
water_pokemon.head()
# Out:
#     Number       Name primary_type secondary_type  Total  HP  Attack  Defense  \
# 6        7   Squirtle        Water            NaN    314  44      48       65
# 7        8  Wartortle        Water            NaN    405  59      63       80
# 8        9  Blastoise        Water            NaN    530  79      83      100
# 53      54    Psyduck        Water            NaN    320  50      52       48
# 54      55    Golduck        Water            NaN    500  80      82       78
#
#     Sp_Atk  Sp_Def  ...   Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 6       50      64  ...    Blue       True    0.875     Monster      Water_1
# 7       65      80  ...    Blue       True    0.875     Monster      Water_1
# 8       85     105  ...    Blue       True    0.875     Monster      Water_1
# 53      65      50  ...  Yellow       True    0.500     Water_1        Field
# 54      95      80  ...    Blue       True    0.500     Water_1        Field
#
# ...

# %%
fire_pokemon=df[df['primary_type']=="Fire"]

# %%
fire_pokemon.head()
# Out:
#     Number        Name primary_type secondary_type  Total  HP  Attack  \
# 3        4  Charmander         Fire            NaN    309  39      52
# 4        5  Charmeleon         Fire            NaN    405  58      64
# 5        6   Charizard         Fire         Flying    534  78      84
# 36      37      Vulpix         Fire            NaN    299  38      41
# 37      38   Ninetales         Fire            NaN    505  73      76
#
#     Defense  Sp_Atk  Sp_Def  ...   Color  hasGender  Pr_Male Egg_Group_1  \
# 3        43      60      50  ...     Red       True    0.875     Monster
# 4        58      80      65  ...     Red       True    0.875     Monster
# 5        78     109      85  ...     Red       True    0.875     Monster
# 36       40      50      65  ...   Brown       True    0.250       Field
# 37       75      81     100  ...  Yellow       True    0.250       Field
#
#     Egg_Group_2  hasMegaEvolution Height_m Weight_kg  Catch_Rate  \
# ...

# %%
df.shape
# Out:
# (721, 23)

# %%
grass_pokemon.shape
# Out:
# (66, 23)

# %%
water_pokemon.shape
# Out:
# (105, 23)

# %%
fire_pokemon.shape
# Out:
# (47, 23)

# %%
(66+105+47)/721
# Out:
# 0.30235783633841884

# %%
grass_pokemon.head()
# Out:
#     Number       Name primary_type secondary_type  Total  HP  Attack  Defense  \
# 0        1  Bulbasaur        Grass         Poison    318  45      49       49
# 1        2    Ivysaur        Grass         Poison    405  60      62       63
# 2        3   Venusaur        Grass         Poison    525  80      82       83
# 42      43     Oddish        Grass         Poison    320  45      50       55
# 43      44      Gloom        Grass         Poison    395  60      65       70
#
#     Sp_Atk  Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0       65      65  ...  Green       True    0.875     Monster        Grass
# 1       80      80  ...  Green       True    0.875     Monster        Grass
# 2      100     100  ...  Green       True    0.875     Monster        Grass
# 42      75      65  ...   Blue       True    0.500       Grass          NaN
# 43      85      75  ...   Blue       True    0.500       Grass          NaN
#
# ...

# %%
sns.histplot(grass_pokemon['Speed'])
plt.show()

# %%
sns.histplot(grass_pokemon['Sp_Atk'])
plt.show()

# %%
sns.histplot(grass_pokemon['Sp_Def'])
plt.show()

# %%
grass_pokemon.describe()
# Out:
#            Number       Total          HP      Attack     Defense      Sp_Atk  \
# count   66.000000   66.000000   66.000000   66.000000   66.000000   66.000000
# mean   347.454545  409.560606   66.196970   70.909091   69.363636   74.333333
# std    200.262380   98.365743   19.394067   24.077904   23.955495   24.570986
# min      1.000000  180.000000   30.000000   27.000000   30.000000   24.000000
# 25%    187.250000  318.000000   50.000000   53.500000   50.000000   55.250000
# 50%    372.000000  409.000000   65.000000   68.000000   65.000000   74.500000
# 75%    507.500000  490.000000   75.000000   89.750000   83.000000   91.500000
# max    673.000000  600.000000  123.000000  130.000000  131.000000  125.000000
#
#            Sp_Def       Speed  Generation    Pr_Male   Height_m   Weight_kg  \
# count   66.000000   66.000000   66.000000  64.000000  66.000000   66.000000
# mean    68.863636   59.893939    3.378788   0.607422   0.984394   38.109091
# ...

# %%
water_pokemon.head()
# Out:
#     Number       Name primary_type secondary_type  Total  HP  Attack  Defense  \
# 6        7   Squirtle        Water            NaN    314  44      48       65
# 7        8  Wartortle        Water            NaN    405  59      63       80
# 8        9  Blastoise        Water            NaN    530  79      83      100
# 53      54    Psyduck        Water            NaN    320  50      52       48
# 54      55    Golduck        Water            NaN    500  80      82       78
#
#     Sp_Atk  Sp_Def  ...   Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 6       50      64  ...    Blue       True    0.875     Monster      Water_1
# 7       65      80  ...    Blue       True    0.875     Monster      Water_1
# 8       85     105  ...    Blue       True    0.875     Monster      Water_1
# 53      65      50  ...  Yellow       True    0.500     Water_1        Field
# 54      95      80  ...    Blue       True    0.500     Water_1        Field
#
# ...

# %%
sns.histplot(water_pokemon['Speed'])
plt.show()

# %%
sns.histplot(water_pokemon['Sp_Atk'])
plt.show()

# %%
sns.histplot(water_pokemon['Sp_Def'])
plt.show()

# %%
water_pokemon.describe()
# Out:
#            Number       Total          HP      Attack     Defense      Sp_Atk  \
# count  105.000000  105.000000  105.000000  105.000000  105.000000  105.000000
# mean   305.895238  417.200000   70.866667   71.047619   70.485714   71.714286
# std    187.287003  102.759091   27.854383   25.030128   25.579858   25.980656
# min      7.000000  200.000000   20.000000   10.000000   20.000000   10.000000
# 25%    131.000000  325.000000   50.000000   52.000000   52.000000   53.000000
# 50%    278.000000  430.000000   69.000000   70.000000   68.000000   70.000000
# 75%    457.000000  495.000000   90.000000   90.000000   85.000000   90.000000
# max    693.000000  680.000000  170.000000  130.000000  180.000000  150.000000
#
#            Sp_Def       Speed  Generation    Pr_Male    Height_m   Weight_kg  \
# count  105.000000  105.000000  105.000000  97.000000  105.000000  105.000000
# mean    68.076190   65.009524    2.885714   0.587629    1.321143   53.576190
# ...

# %%
grass_pokemon.describe()
# Out:
#            Number       Total          HP      Attack     Defense      Sp_Atk  \
# count   66.000000   66.000000   66.000000   66.000000   66.000000   66.000000
# mean   347.454545  409.560606   66.196970   70.909091   69.363636   74.333333
# std    200.262380   98.365743   19.394067   24.077904   23.955495   24.570986
# min      1.000000  180.000000   30.000000   27.000000   30.000000   24.000000
# 25%    187.250000  318.000000   50.000000   53.500000   50.000000   55.250000
# 50%    372.000000  409.000000   65.000000   68.000000   65.000000   74.500000
# 75%    507.500000  490.000000   75.000000   89.750000   83.000000   91.500000
# max    673.000000  600.000000  123.000000  130.000000  131.000000  125.000000
#
#            Sp_Def       Speed  Generation    Pr_Male   Height_m   Weight_kg  \
# count   66.000000   66.000000   66.000000  64.000000  66.000000   66.000000
# mean    68.863636   59.893939    3.378788   0.607422   0.984394   38.109091
# ...

# %%
sns.histplot(fire_pokemon['Speed'],color='red')
plt.show()

# %%
sns.histplot(fire_pokemon['Sp_Atk'],color='red')
plt.show()

# %%
sns.histplot(fire_pokemon['Sp_Def'],color='red')
plt.show()

# %%
fire_pokemon.describe()
# Out:
#            Number       Total          HP      Attack     Defense      Sp_Atk  \
# count   47.000000   47.000000   47.000000   47.000000   47.000000   47.000000
# mean   337.829787  443.021277   68.595745   82.212766   64.893617   83.468085
# std    225.660992  103.756297   19.592212   25.361676   22.654526   25.788311
# min      4.000000  250.000000   38.000000   40.000000   37.000000   15.000000
# 25%    150.500000  357.500000   56.500000   61.500000   46.500000   67.500000
# 50%    322.000000  460.000000   65.000000   84.000000   60.000000   80.000000
# 75%    513.500000  529.000000   79.000000   99.000000   72.000000  104.500000
# max    721.000000  680.000000  115.000000  140.000000  140.000000  130.000000
#
#            Sp_Def       Speed  Generation    Pr_Male   Height_m   Weight_kg  \
# count   47.000000   47.000000   47.000000  43.000000  47.000000   47.000000
# mean    69.468085   74.382979    3.276596   0.683140   1.163617   63.976596
# ...

# %%
water_pokemon.describe()
# Out:
#            Number       Total          HP      Attack     Defense      Sp_Atk  \
# count  105.000000  105.000000  105.000000  105.000000  105.000000  105.000000
# mean   305.895238  417.200000   70.866667   71.047619   70.485714   71.714286
# std    187.287003  102.759091   27.854383   25.030128   25.579858   25.980656
# min      7.000000  200.000000   20.000000   10.000000   20.000000   10.000000
# 25%    131.000000  325.000000   50.000000   52.000000   52.000000   53.000000
# 50%    278.000000  430.000000   69.000000   70.000000   68.000000   70.000000
# 75%    457.000000  495.000000   90.000000   90.000000   85.000000   90.000000
# max    693.000000  680.000000  170.000000  130.000000  180.000000  150.000000
#
#            Sp_Def       Speed  Generation    Pr_Male    Height_m   Weight_kg  \
# count  105.000000  105.000000  105.000000  97.000000  105.000000  105.000000
# mean    68.076190   65.009524    2.885714   0.587629    1.321143   53.576190
# ...

# %%
df.head()
# Out:
#    Number        Name primary_type secondary_type  Total  HP  Attack  Defense  \
# 0       1   Bulbasaur        Grass         Poison    318  45      49       49
# 1       2     Ivysaur        Grass         Poison    405  60      62       63
# 2       3    Venusaur        Grass         Poison    525  80      82       83
# 3       4  Charmander         Fire            NaN    309  39      52       43
# 4       5  Charmeleon         Fire            NaN    405  58      64       58
#
#    Sp_Atk  Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65      65  ...  Green       True    0.875     Monster        Grass
# 1      80      80  ...  Green       True    0.875     Monster        Grass
# 2     100     100  ...  Green       True    0.875     Monster        Grass
# 3      60      50  ...    Red       True    0.875     Monster       Dragon
# 4      80      65  ...    Red       True    0.875     Monster       Dragon
#
# ...

# %%
cols_to_drops = ['Pr_Male','Egg_Group_1','Egg_Group_2','hasMegaEvolution']
df.drop(columns=cols_to_drops, inplace=True)

# %%
df.head()
# Out:
#    Number        Name primary_type secondary_type  Total  HP  Attack  Defense  \
# 0       1   Bulbasaur        Grass         Poison    318  45      49       49
# 1       2     Ivysaur        Grass         Poison    405  60      62       63
# 2       3    Venusaur        Grass         Poison    525  80      82       83
# 3       4  Charmander         Fire            NaN    309  39      52       43
# 4       5  Charmeleon         Fire            NaN    405  58      64       58
#
#    Sp_Atk  Sp_Def  Speed  Generation  isLegendary  Color  hasGender  Height_m  \
# 0      65      65     45           1        False  Green       True      0.71
# 1      80      80     60           1        False  Green       True      0.99
# 2     100     100     80           1        False  Green       True      2.01
# 3      60      50     65           1        False    Red       True      0.61
# 4      80      65     80           1        False    Red       True      1.09
#
# ...

# %%
df['isLegendary'].value_counts()
# Out:
# False    675
# True      46
# Name: isLegendary, dtype: int64

# %%
(46/721)
# Out:
# 0.0638002773925104

# %%
df.shape
# Out:
# (721, 19)

# %%
# now we want to classify pokemon is legendary or not on the basis of Speed
x = df[['Speed']]# independent
y = df[['isLegendary']]#dependent

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dtc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[206,   8],
#        [  1,   2]], dtype=int64)

# %%
(206+2)/(206+2+1+8)
# Out:
# 0.9585253456221198

# %%
# we can perform both regression and classification with decision tree
df.head()
# Out:
#    Number        Name primary_type secondary_type  Total  HP  Attack  Defense  \
# 0       1   Bulbasaur        Grass         Poison    318  45      49       49
# 1       2     Ivysaur        Grass         Poison    405  60      62       63
# 2       3    Venusaur        Grass         Poison    525  80      82       83
# 3       4  Charmander         Fire            NaN    309  39      52       43
# 4       5  Charmeleon         Fire            NaN    405  58      64       58
#
#    Sp_Atk  Sp_Def  Speed  Generation  isLegendary  Color  hasGender  Height_m  \
# 0      65      65     45           1        False  Green       True      0.71
# 1      80      80     60           1        False  Green       True      0.99
# 2     100     100     80           1        False  Green       True      2.01
# 3      60      50     65           1        False    Red       True      0.61
# 4      80      65     80           1        False    Red       True      1.09
#
# ...

# %%
x = df[['Defense']]

# %%
y = df[['Attack']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()

# %%
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtr.predict(x_test)

# %%
y_test.head()
# Out:
#      Attack
# 107      55
# 314      60
# 528      85
# 318     120
# 493     100

# %%
y_pred[0:5]
# Out:
# array([91.9375    , 62.05      , 53.96153846, 53.96153846, 97.73684211])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 619.6338241318266
